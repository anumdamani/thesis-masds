# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", dtype={'year': 'Int64'})
bestseller_count = data[data['label'] == 1].shape[0]
non_bestseller_count = data[data['label'] == 0].shape[0]

print(f"Number of Bestsellers: {bestseller_count}")
print(f"Number of Non-Bestsellers: {non_bestseller_count}")
# Out:
# Number of Bestsellers: 2216
# Number of Non-Bestsellers: 2450

# %%
min_year_bestseller = data[data['label'] == 1]['year'].min()
min_year_non_bestseller = data[data['label'] == 0]['year'].min()
max_year_bestseller = data[data['label'] == 1]['year'].max()
max_year_non_bestseller = data[data['label'] == 0]['year'].max()
print(f"Minimum Year for Bestsellers: {min_year_bestseller}")
print(f"Minimum Year for Non-Bestsellers: {min_year_non_bestseller}")
print(f"Max Year for Bestsellers: {max_year_bestseller}")
print(f"Max Year for Non-Bestsellers: {max_year_non_bestseller}")
# Out:
# Minimum Year for Bestsellers: 1962
# Minimum Year for Non-Bestsellers: 2010
# Max Year for Bestsellers: 2025
# Max Year for Non-Bestsellers: 2024

# %%
data['year'] = data['year'].astype('Int64')

# %%
data['year']
# Out:
# 0       2010
# 1       2010
# 2       2012
# 3       2013
# 4       2010
#         ...
# 4661    2020
# 4662    2024
# 4663    <NA>
# 4664    2024
# 4665    2020
# Name: year, Length: 4666, dtype: Int64

# %%
data.to_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", index=False)
print("Dataset updated and saved.")
# Out:
# Dataset updated and saved.

# %%
data
# Out:
#                                  title  \
# 0                           Mockingjay
# 1               The Fault in Our Stars
# 2                  Bring Up the Bodies
# 3     The Ocean at the End of the Lane
# 4                          The Passage
# ...                                ...
# 4661              THE PERFECT MARRIAGE
# 4662                       QUICKSILVER
# 4663      TOM CLANCY: DEFENSE PROTOCOL
# 4664                    WIND AND TRUTH
# 4665           SMALL THINGS LIKE THESE
#
#                                                  author  year  \
# 0                                       Suzanne Collins  2010
# 1                                            John Green  2010
# 2                                         Hilary Mantel  2012
# 3     Neil Gaiman, Mónica Faerna, Patrick Marcel, Ll...  2013
# 4                                         Justin Cronin  2010
# ...                                                 ...   ...
# ...

# %%
import pandas as pd
df = pd.read_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", dtype={'year': 'Int64'})

# %%
df
# Out:
#                                  title  \
# 0                           Mockingjay
# 1               The Fault in Our Stars
# 2                  Bring Up the Bodies
# 3     The Ocean at the End of the Lane
# 4                          The Passage
# ...                                ...
# 4661              THE PERFECT MARRIAGE
# 4662                       QUICKSILVER
# 4663      TOM CLANCY: DEFENSE PROTOCOL
# 4664                    WIND AND TRUTH
# 4665           SMALL THINGS LIKE THESE
#
#                                                  author  year  \
# 0                                       Suzanne Collins  2010
# 1                                            John Green  2010
# 2                                         Hilary Mantel  2012
# 3     Neil Gaiman, Mónica Faerna, Patrick Marcel, Ll...  2013
# 4                                         Justin Cronin  2010
# ...                                                 ...   ...
# ...

# %%
#df[df["title"] == "NYPD RED 3"]
df.loc[df["title"] == "NYPD RED 3", "year"] = 2015

# %%
df[df["title"] == "NYPD RED 3"]
# Out:
#            title                             author    year  \
# 2537  NYPD RED 3  James Patterson and Marshall Karp  2015.0
#
#                                               cover_url  \
# 2537  https://storage.googleapis.com/du-prd/books/im...
#
#                                             description  label  num_assigned  \
# 2537  Investigating the disappearance of a billionai...      1          2538
#
#      image_name
# 2537   2538.jpg

# %%
df.to_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", index=False)
print("Dataset updated and saved.")
# Out:
# Dataset updated and saved.

# %%
#df[df["year"] == 1790.0]
df.loc[df["title"] == "I ALMOST FORGOT ABOUT YOU", "year"] = 2016
df[df["title"] == "I ALMOST FORGOT ABOUT YOU"]
df.to_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", index=False)
print("Dataset updated and saved.")
# Out:
# Dataset updated and saved.

# %%
df
# Out:
#                                  title  \
# 0                           Mockingjay
# 1               The Fault in Our Stars
# 2                  Bring Up the Bodies
# 3     The Ocean at the End of the Lane
# 4                          The Passage
# ...                                ...
# 4661              THE PERFECT MARRIAGE
# 4662                       QUICKSILVER
# 4663      TOM CLANCY: DEFENSE PROTOCOL
# 4664                    WIND AND TRUTH
# 4665           SMALL THINGS LIKE THESE
#
#                                                  author    year  \
# 0                                       Suzanne Collins  2010.0
# 1                                            John Green  2010.0
# 2                                         Hilary Mantel  2012.0
# 3     Neil Gaiman, Mónica Faerna, Patrick Marcel, Ll...  2013.0
# 4                                         Justin Cronin  2010.0
# ...                                                 ...     ...
# ...

# %%
missing_image_names = df[df["image_name"].isnull()]
missing_image_names
# Out:
# Empty DataFrame
# Columns: [title, author, year, cover_url, description, label, num_assigned, image_name]
# Index: []

# %%
df
# Out:
#                                  title  \
# 0                           Mockingjay
# 1               The Fault in Our Stars
# 2                  Bring Up the Bodies
# 3     The Ocean at the End of the Lane
# 4                          The Passage
# ...                                ...
# 4661              THE PERFECT MARRIAGE
# 4662                       QUICKSILVER
# 4663      TOM CLANCY: DEFENSE PROTOCOL
# 4664                    WIND AND TRUTH
# 4665           SMALL THINGS LIKE THESE
#
#                                                  author    year  \
# 0                                       Suzanne Collins  2010.0
# 1                                            John Green  2010.0
# 2                                         Hilary Mantel  2012.0
# 3     Neil Gaiman, Mónica Faerna, Patrick Marcel, Ll...  2013.0
# 4                                         Justin Cronin  2010.0
# ...                                                 ...     ...
# ...

# %% [markdown]
# ## March 3

# %%
# Find the earliest year in bestsellers
earliest_bestseller_year = df[df['label'] == 1]['year'].min()

# Find the earliest year in non-bestsellers
earliest_nonbestseller_year = df[df['label'] == 0]['year'].min()

print("Earliest year in bestsellers:", earliest_bestseller_year)
print("Earliest year in non-bestsellers:", earliest_nonbestseller_year)
# Out:
# Earliest year in bestsellers: 1900.0
# Earliest year in non-bestsellers: 2010.0

# %%
# Filter bestsellers with year less than 2015
bestsellers_before_2015 = df[(df['label'] == 1) & (df['year'] < 2000)]

# Display the results
bestsellers_before_2015

# NEED TO CHECK THESE YEARS TO MAKE SURE THEY ARE ACCURATE

# THE ESCAPE = 2014
# THE BURIED GIANT = 2015
# THE LIAR = 2015
# THE WAY TO A MAN'S HEART = 1997
# DANCE UPON THE AIR = 2001
# 11/22/63 = 2011
# IT = 1986
# THE GUNSLINGER = 1982
# CIRCE = 2018
# SHADOW KEEPER = 2016
# SHELTER IN PLACE = 2018
# THE NEXT PERSON YOU MEET IN HEAVEN = 2018
# THE UNHONEYMOONERS = 2019
# TOM CLANCY: FIRING POINT = 2020
# ETERNAL = 2021

import pandas as pd
year_updates = {
    "THE ESCAPE": 2014,
    "THE BURIED GIANT": 2015,
    "THE LIAR": 2015,
    "THE WAY TO A MAN'S HEART": 1997,
    "DANCE UPON THE AIR": 2001,
    "11/22/63": 2011,
    "IT": 1986,
    "THE GUNSLINGER": 1982,
    "CIRCE": 2018,
    "SHADOW KEEPER": 2016,
    "SHELTER IN PLACE": 2018,
    "THE NEXT PERSON YOU MEET IN HEAVEN": 2018,
    "THE UNHONEYMOONERS": 2019,
    "TOM CLANCY: FIRING POINT": 2020,
    "ETERNAL": 2021
}

# Update the DataFrame
bestsellers_before_2015.loc[
    bestsellers_before_2015['title'].isin(year_updates.keys()), 'year'
] = bestsellers_before_2015['title'].map(year_updates)

# Display updated DataFrame
print(bestsellers_before_2015)
# Out:
#                                    title            author    year  \
# 2455                          THE ESCAPE    David Baldacci  2014.0
# 2463                       THE ALCHEMIST      Paulo Coelho  1988.0
# 2525                       TOTAL CONTROL    David Baldacci  1996.0
# 2526                    THE BURIED GIANT    Kazuo Ishiguro  2015.0
# 2552                           OUTLANDER    Diana Gabaldon  1991.0
# 2563                            THE LIAR      Nora Roberts  2015.0
# 2705            THE WAY TO A MAN'S HEART   Debbie Macomber  1997.0
# 2729                  DANCE UPON THE AIR      Nora Roberts  2001.0
# 2766                      SEVENTH HEAVEN     Alice Hoffman  1990.0
# 2772          THE MAN IN THE HIGH CASTLE     Philip K Dick  1962.0
# 2773                         NIGHT MOVES      Nora Roberts  1985.0
# 2819                   A TASTE FOR DEATH         P D James  1986.0
# 2823                 UNFINISHED BUSINESS      Nora Roberts  1992.0
# ...

# %%
import pandas as pd

# the years for these books are ones I had to find manually, through Google Search
year_updates = {
    "THE ESCAPE": 2014,
    "THE BURIED GIANT": 2015,
    "THE LIAR": 2015,
    "THE WAY TO A MAN'S HEART": 1997,
    "DANCE UPON THE AIR": 2001,
    "11/22/63": 2011,
    "IT": 1986,
    "THE GUNSLINGER": 1982,
    "CIRCE": 2018,
    "SHADOW KEEPER": 2016,
    "SHELTER IN PLACE": 2018,
    "THE NEXT PERSON YOU MEET IN HEAVEN": 2018,
    "THE UNHONEYMOONERS": 2019,
    "TOM CLANCY: FIRING POINT": 2020,
    "ETERNAL": 2021
}

# Update the DataFrame
df.loc[
    df['title'].isin(year_updates.keys()), 'year'
] = df['title'].map(year_updates)

# Display updated DataFrame
print(df)
# Out:
#                                  title  \
# 0                           Mockingjay
# 1               The Fault in Our Stars
# 2                  Bring Up the Bodies
# 3     The Ocean at the End of the Lane
# 4                          The Passage
# ...                                ...
# 4661              THE PERFECT MARRIAGE
# 4662                       QUICKSILVER
# 4663      TOM CLANCY: DEFENSE PROTOCOL
# 4664                    WIND AND TRUTH
# 4665           SMALL THINGS LIKE THESE
#
#                                                  author    year  \
# 0                                       Suzanne Collins  2010.0
# 1                                            John Green  2010.0
# 2                                         Hilary Mantel  2012.0
# 3     Neil Gaiman, Mónica Faerna, Patrick Marcel, Ll...  2013.0
# 4                                         Justin Cronin  2010.0
# ...                                                 ...     ...
# ...

# %%
# Find the earliest year in bestsellers
earliest_bestseller_year = df[df['label'] == 1]['year'].min()

# Find the earliest year in non-bestsellers
earliest_nonbestseller_year = df[df['label'] == 0]['year'].min()

print("Earliest year in bestsellers:", earliest_bestseller_year)
print("Earliest year in non-bestsellers:", earliest_nonbestseller_year)
# Out:
# Earliest year in bestsellers: 1962.0
# Earliest year in non-bestsellers: 2010.0

# %%
# Filter the dataframe to find the book from 1755 in bestsellers
earliest_bestseller_book = df[(df['label'] == 1) & (df['year'] == 1755)]

# Display the book(s)
print(earliest_bestseller_book)
# Out:
# Empty DataFrame
# Columns: [title, author, year, cover_url, description, label, num_assigned, image_name]
# Index: []

# %%
# Filter bestsellers with year less than 2015
bestsellers_before_2015 = df[(df['label'] == 1) & (df['year'] < 1940)]

# Display the results
bestsellers_before_2015
# Out:
# Empty DataFrame
# Columns: [title, author, year, cover_url, description, label, num_assigned, image_name]
# Index: []

# %%
# UPDATING THE DATASET
df.to_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", index=False)
print("Dataset updated successfully!")
# Out:
# Dataset updated successfully!

# %%
# Filter bestsellers with year less than 2015
bestsellers_before_2015 = df[(df['label'] == 1) & (df['year'] < 1940)]

# Display the results
bestsellers_before_2015
# Out:
# Empty DataFrame
# Columns: [title, author, year, cover_url, description, label, num_assigned, image_name]
# Index: []

# %% [markdown]
# # CREATING PLOTS

# %%
df = pd.read_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv")

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Drop missing values in 'year' and convert to integers
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# Filter dataset to include only books from 2000 onwards
df_filtered = df[df['year'] >= 2000]

# Separate bestsellers and non-bestsellers
bestsellers = df_filtered[df_filtered['label'] == 1]
non_bestsellers = df_filtered[df_filtered['label'] == 0]

# Create figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10), sharex=True)

# Histogram for bestsellers
axes[0].hist(bestsellers['year'], bins=range(2000, df_filtered['year'].max() + 1), color='blue', edgecolor='black', alpha=0.7)
axes[0].set_title("Number of Bestsellers Published Per Year (2000-Present)")
axes[0].set_ylabel("Count of Bestsellers")
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Histogram for non-bestsellers
axes[1].hist(non_bestsellers['year'], bins=range(2000, df_filtered['year'].max() + 1), color='red', edgecolor='black', alpha=0.7)
axes[1].set_title("Number of Non-Bestsellers Published Per Year (2000-Present)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Count of Non-Bestsellers")
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Separate bestsellers and non-bestsellers
bestseller_words = ' '.join(data[data['label'] == 1]['clean_text']).split()
non_bestseller_words = ' '.join(data[data['label'] == 0]['clean_text']).split()

# Count word frequencies
bestseller_freq = Counter(bestseller_words)
non_bestseller_freq = Counter(non_bestseller_words)

# Get most common words in bestsellers
bestseller_top_words = bestseller_freq.most_common(20)
non_bestseller_top_words = non_bestseller_freq.most_common(20)

print("Top words in bestsellers:", bestseller_top_words)
print("Top words in non-bestsellers:", non_bestseller_top_words)

# Convert word frequency data into a DataFrame
bestseller_df = pd.DataFrame(bestseller_top_words, columns=['word', 'count'])
non_bestseller_df = pd.DataFrame(non_bestseller_top_words, columns=['word', 'count'])

# Plot side-by-side bar plots for comparison
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

sns.barplot(x='count', y='word', data=bestseller_df, ax=axes[0], palette='Blues_r')
axes[0].set_title('Top Words in Bestsellers')
axes[0].set_xlabel('Frequency')

sns.barplot(x='count', y='word', data=non_bestseller_df, ax=axes[1], palette='Reds_r')
axes[1].set_title('Top Words in Non-Bestsellers')
axes[1].set_xlabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Top words in bestsellers: [('series', 565), ('book', 537), ('woman', 209), ('new', 174), ('family', 153), ('life', 125), ('must', 123), ('man', 122), ('find', 122), ('detective', 105), ('murder', 102), ('go', 96), ('two', 95), ('secret', 91), ('killer', 87), ('war', 85), ('former', 85), ('novel', 80), ('take', 79), ('death', 79)]
# Top words in non-bestsellers: [('one', 866), ('life', 717), ('new', 689), ('find', 578), ('world', 521), ('love', 485), ('time', 470), ('friend', 438), ('story', 425), ('de', 405), ('family', 400), ('und', 389), ('die', 388), ('book', 370), ('year', 365), ('man', 356), ('know', 354), ('must', 335), ('way', 333), ('woman', 330)]

# %%
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Function to filter valid words
def filter_complete_words(words):
    return [word for word in words if word.isalpha() and len(word) > 2]  # Keep only alphabetic words with length > 1

# Separate bestsellers and non-bestsellers
bestseller_words = ' '.join(data[data['label'] == 1]['clean_text']).split()
non_bestseller_words = ' '.join(data[data['label'] == 0]['clean_text']).split()

# Filter only complete words
bestseller_words = filter_complete_words(bestseller_words)
non_bestseller_words = filter_complete_words(non_bestseller_words)

# Count word frequencies
bestseller_freq = Counter(bestseller_words)
non_bestseller_freq = Counter(non_bestseller_words)

# Get most common words in bestsellers
bestseller_top_words = bestseller_freq.most_common(10)
non_bestseller_top_words = non_bestseller_freq.most_common(10)

print("Top words in bestsellers:", bestseller_top_words)
print("Top words in non-bestsellers:", non_bestseller_top_words)

# Convert word frequency data into a DataFrame
bestseller_df = pd.DataFrame(bestseller_top_words, columns=['word', 'count'])
non_bestseller_df = pd.DataFrame(non_bestseller_top_words, columns=['word', 'count'])

# Plot side-by-side bar plots for comparison
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

sns.barplot(x='count', y='word', data=bestseller_df, ax=axes[0], palette='Blues_r')
axes[0].set_title('Top Words in Bestsellers')
axes[0].set_xlabel('Frequency')

sns.barplot(x='count', y='word', data=non_bestseller_df, ax=axes[1], palette='Reds_r')
axes[1].set_title('Top Words in Non-Bestsellers')
axes[1].set_xlabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Top words in bestsellers: [('series', 565), ('book', 537), ('woman', 209), ('new', 174), ('family', 153), ('life', 125), ('must', 123), ('man', 122), ('find', 122), ('detective', 105)]
# Top words in non-bestsellers: [('one', 866), ('life', 717), ('new', 689), ('find', 578), ('world', 521), ('love', 485), ('time', 470), ('friend', 438), ('story', 425), ('family', 400)]

# %%
non_bestseller_top_words
# Out:
# [('one', 866),
#  ('life', 717),
#  ('new', 689),
#  ('find', 578),
#  ('world', 521),
#  ('love', 485),
#  ('time', 470),
#  ('friend', 438),
#  ('story', 425),
#  ('family', 400)]

# %%
# Drop rows where 'year' is missing and convert to integers
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# Filter dataset to include only books from the year 2015 onwards
df2 = df[df['year'] >= 2015]

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# Create a dictionary to store word frequencies by year
word_trends = {word: [] for word, _ in bestseller_top_words}

# Get sorted years from 2000 onwards
years = sorted(df2['year'].unique())

# Iterate over years and count word occurrences in bestseller descriptions
for year in years:
    yearly_text = ' '.join(df2[(df2['label'] == 1) & (df2['year'] == year)]['clean_text']).split()
    yearly_counts = Counter(yearly_text)
    
    # Store word frequencies
    for word in word_trends:
        word_trends[word].append(yearly_counts.get(word, 0))  # Default to 0 if word not found

# Convert dictionary to DataFrame
trend_df = pd.DataFrame(word_trends, index=years)

# Plot the trends
plt.figure(figsize=(12, 6))
for word in bestseller_top_words[:5]:  # Plot only the top 5 words for clarity
    plt.plot(trend_df.index, trend_df[word[0]], marker='o', label=word[0])

plt.title("Word Frequency Trends in Bestsellers (2015-Present)")
plt.xlabel("Year")
plt.ylabel("Word Count in Descriptions")
plt.xticks(rotation=45)  
plt.legend(title="Words")
plt.grid(True)
plt.show()
# Out:
# /var/folders/nk/xkv_bvtx08jfbpgtwjq7tbdm0000gn/T/ipykernel_14833/948503473.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# Drop NaN values in 'year' and convert to int
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# Filter data from 2010 onwards
df3 = df[df['year'] >= 2015]

# Extract only words from non_bestseller_top_words (ignoring counts)
top_words = [word[0] for word in non_bestseller_top_words]

# Create a dictionary to store word frequencies by year
word_trends = {word: [] for word in top_words}

# Get sorted years from 2010 onwards
years = sorted(df3['year'].unique())

# Iterate over years and count word occurrences in non-bestseller descriptions
for year in years:
    yearly_text = ' '.join(df3[(df3['label'] == 0) & (df3['year'] == year)]['clean_text']).split()
    yearly_counts = Counter(yearly_text)
    
    # Store word frequencies
    for word in word_trends:
        word_trends[word].append(yearly_counts.get(word, 0))  # Default to 0 if word not found

# Convert dictionary to DataFrame
trend_df = pd.DataFrame(word_trends, index=years)

# Plot the trends
plt.figure(figsize=(12, 6))
for word in top_words[:5]:  # Plot only the top 5 words for clarity
    plt.plot(trend_df.index, trend_df[word], marker='o', label=word)

plt.title("Word Frequency Trends in Non-Bestsellers (2015-Present)")
plt.xlabel("Year")
plt.ylabel("Word Count in Descriptions")
plt.xticks(rotation=45)
plt.legend(title="Words")
plt.grid(True)
plt.show()

# %%
print(non_bestseller_top_words)
# Out:
# ['one', 'life', 'new', 'find', 'world', 'love', 'time', 'friend', 'story', 'family']

# %%
non_bestseller_top_words
# Out:
# [('one', 866),
#  ('life', 717),
#  ('new', 689),
#  ('find', 578),
#  ('world', 521),
#  ('love', 485),
#  ('time', 470),
#  ('friend', 438),
#  ('story', 425),
#  ('family', 400)]

# %%
df_counts = df.groupby(['year', 'label']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 6))
plt.plot(df_counts.index, df_counts[0], label='Non-Bestsellers', marker='o')
plt.plot(df_counts.index, df_counts[1], label='Bestsellers', marker='o', linestyle='dashed')

plt.xlabel("Year")
plt.ylabel("Number of Books")
plt.title("Bestseller vs. Non-Bestseller Trends Over Time")
plt.legend()
plt.grid(True)
plt.show()

# %%
bestseller_authors = df[df['label'] == 1]['author'].value_counts().head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=bestseller_authors.values, y=bestseller_authors.index, palette="viridis")
plt.xlabel("Number of Bestsellers")
plt.ylabel("Author")
plt.title("Top 10 Authors with the Most Bestsellers")
plt.show()

# %%
# April 8, 2025
import pandas as pd
bestsellers = pd.read_csv("/Users/anumdamani/thesis/nyt_fiction_data_21025/nyt_fiction_official.csv", dtype={'year': 'Int64'})
bestsellers['year'] = bestsellers['year'].astype('Int64') 
bestsellers.columns
bestsellers.head()
# Out:
#                               title          author  year  \
# 0                  EDGE OF ETERNITY     Ken Follett  2014
# 1                           REVIVAL    Stephen King  2014
# 2                   BIG LITTLE LIES  Liane Moriarty  2014
# 3  TOM CLANCY FULL FORCE AND EFFECT    Mark Greaney  2014
# 4                     GRAY MOUNTAIN    John Grisham  2014
#
#                                            cover_url  \
# 0  https://storage.googleapis.com/du-prd/books/im...
# 1  https://storage.googleapis.com/du-prd/books/im...
# 2  https://storage.googleapis.com/du-prd/books/im...
# 3  https://storage.googleapis.com/du-prd/books/im...
# 4  https://storage.googleapis.com/du-prd/books/im...
#
#                                          description  label
# 0  In Book 3 of the Century trilogy, five interco...      1
# 1  The continuing relationship over five decades ...      1
# 2  Who will end up dead, and how, when three moth...      1
# ...

# %%
# Filter
bestseller_lengths = bestsellers['description'].apply(len)
#nonbestseller_lengths = nonbestsellers['clean_text'].apply(len)
print("Average length (bestsellers):", bestseller_lengths.mean())
#print("Average length (nonbestsellers):", nonbestseller_lengths.mean())
# Out:
# Average length (bestsellers): 109.40929602888086

# %%
nonbestsellers = pd.read_csv("/Users/anumdamani/thesis/non_nyt_fiction_data_21025/non_NYT_fiction_official.csv", dtype={'year': 'Int64'})
nonbestseller_lengths = nonbestsellers['description'].apply(len)
print("Average length (nonbestsellers):", nonbestseller_lengths.mean())
# Out:
# Average length (nonbestsellers): 580.8236734693877

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# Get the texts for bestsellers and non-bestsellers
df = pd.read_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", dtype={'year': 'Int64'})
bestseller_texts = df[df['label'] == 1]['title']
non_bestseller_texts = df[df['label'] == 0]['title']

# Function to create the word cloud
def create_wordcloud(texts, title, ax):
    # TF-IDF Vectorization
    vectorizer = TfidfVectorizer(max_features=50, stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    # Get the words and their corresponding TF-IDF scores
    tfidf_scores = dict(zip(vectorizer.get_feature_names_out(), X.sum(axis=0).A1))
    
    # Create the WordCloud
    wordcloud = WordCloud(background_color="white", width=800, height=400, max_words=50).generate_from_frequencies(tfidf_scores)
    
    # Plot the word cloud
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis("off")
    ax.set_title(title)

# Plot WordClouds for Bestsellers and Non-Bestsellers
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

create_wordcloud(bestseller_texts, "Word Cloud of Important Words in Bestselling Book Titles", ax[0])
create_wordcloud(non_bestseller_texts, "Word Cloud of Important Words in Non-Bestselling Book Titles", ax[1])

# Save both word clouds separately
fig.savefig('/Users/anumdamani/thesis/EDA/wordcloud_bestsellers_and_nonbestsellers_titles.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# Get the texts for bestsellers and non-bestsellers
df = pd.read_csv("/Users/anumdamani/thesis/fiction_combined_21025/updated_fiction_official.csv", dtype={'year': 'Int64'})
bestseller_texts = df[df['label'] == 1]['clean_text']
non_bestseller_texts = df[df['label'] == 0]['clean_text']

# Function to create the word cloud
def create_wordcloud(texts, title, ax):
    # TF-IDF Vectorization
    vectorizer = TfidfVectorizer(max_features=50, stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    # Get the words and their corresponding TF-IDF scores
    tfidf_scores = dict(zip(vectorizer.get_feature_names_out(), X.sum(axis=0).A1))
    
    # Create the WordCloud
    wordcloud = WordCloud(background_color="white", width=800, height=400, max_words=50).generate_from_frequencies(tfidf_scores)
    
    # Plot the word cloud
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis("off")
    ax.set_title(title)

# Plot WordClouds for Bestsellers and Non-Bestsellers
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

create_wordcloud(bestseller_texts, "Word Cloud of Important Words in Bestselling Book Descriptions", ax[0])
create_wordcloud(non_bestseller_texts, "Word Cloud of Important Words in Non-Bestselling Book Descriptions", ax[1])

# Save both word clouds separately
fig.savefig('/Users/anumdamani/thesis/EDA/wordcloud_bestsellers_and_nonbestsellers_descriptions.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd

bestseller_color = '#E69F00' # orange
non_bestseller_color = '#56B4E9' # light blue

# Get the texts for bestsellers and non-bestsellers
bestseller_texts = df[df['label'] == 1]['clean_text']
non_bestseller_texts = df[df['label'] == 0]['clean_text']

# Function to calculate sentiment polarity
def get_sentiment_polarity(text):
    return TextBlob(text).sentiment.polarity

# Apply the sentiment analysis function to both bestsellers and non-bestsellers
bestseller_polarities = bestseller_texts.apply(get_sentiment_polarity)
non_bestseller_polarities = non_bestseller_texts.apply(get_sentiment_polarity)

# Plotting the sentiment distribution
plt.figure(figsize=(10, 6))

# Plot for Bestsellers
plt.hist(bestseller_polarities, bins=20, alpha=0.7, label="Bestsellers", color=bestseller_color)

# Plot for Non-Bestsellers
plt.hist(non_bestseller_polarities, bins=20, alpha=0.7, label="Non-Bestsellers", color=non_bestseller_color)

# Customizing the plot
plt.title("Sentiment Polarity Distribution of Book Descriptions for Bestsellers vs. Non-Bestsellers")
plt.xlabel("Sentiment Polarity")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.savefig("/Users/anumdamani/thesis/EDA/sentiment_polarity_distribution.png", dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
mean_bestseller_polarity = bestseller_polarities.mean()
mean_non_bestseller_polarity = non_bestseller_polarities.mean()

print(f"Mean sentiment polarity of Bestsellers: {mean_bestseller_polarity}")
print(f"Mean sentiment polarity of Non-Bestsellers: {mean_non_bestseller_polarity}")
# Out:
# Mean sentiment polarity of Bestsellers: -0.0011235878291383705
# Mean sentiment polarity of Non-Bestsellers: 0.07446870920583655

# %%
# !pip install --upgrade text2emotion
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

bestsellers = pd.read_csv("/Users/anumdamani/thesis/nyt_fiction_data_21025/nyt_fiction_official.csv", dtype={'year': 'Int64'})
nonbestsellers = pd.read_csv("/Users/anumdamani/thesis/non_nyt_fiction_data_21025/non_NYT_fiction_official.csv", dtype={'year': 'Int64'})

# %%
# !pip install vaderSentiment
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Apply VADER sentiment analysis to book descriptions
def get_vader_sentiment(text):
    sentiment = analyzer.polarity_scores(str(text))
    return sentiment

bestsellers['vader_sentiment'] = bestsellers['description'].apply(get_vader_sentiment)
nonbestsellers['vader_sentiment'] = nonbestsellers['description'].apply(get_vader_sentiment)

# Check the sentiment scores
print(bestsellers[['title', 'vader_sentiment']].head())
print(nonbestsellers[['title', 'vader_sentiment']].head())
# Out:
#                               title  \
# 0                  EDGE OF ETERNITY
# 1                           REVIVAL
# 2                   BIG LITTLE LIES
# 3  TOM CLANCY FULL FORCE AND EFFECT
# 4                     GRAY MOUNTAIN
#
#                                      vader_sentiment
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...
# 2  {'neg': 0.184, 'neu': 0.684, 'pos': 0.132, 'co...
# 3  {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'comp...
# 4  {'neg': 0.081, 'neu': 0.852, 'pos': 0.067, 'co...
#                               title  \
# 0                        Mockingjay
# 1            The Fault in Our Stars
# 2               Bring Up the Bodies
# 3  The Ocean at the End of the Lane
# 4                       The Passage
#
#                                      vader_sentiment
# 0  {'neg': 0.267, 'neu': 0.573, 'pos': 0.16, 'com...
# 1  {'neg': 0.093, 'neu': 0.732, 'pos': 0.175, 'co...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Function to get the compound sentiment score
def get_compound_sentiment(text):
    return sia.polarity_scores(text)['compound']

# Apply the function to the description
bestsellers['compound_sentiment'] = bestsellers['description'].apply(get_compound_sentiment)
nonbestsellers['compound_sentiment'] = nonbestsellers['description'].apply(get_compound_sentiment)
# Calculate the average compound sentiment for each group
avg_bestseller_sentiment = bestsellers['compound_sentiment'].mean()
avg_nonbestseller_sentiment = nonbestsellers['compound_sentiment'].mean()

# Create a DataFrame for plotting
sentiment_data = pd.DataFrame({
    'Group': ['Bestsellers', 'Non-Bestsellers'],
    'Average Sentiment': [avg_bestseller_sentiment, avg_nonbestseller_sentiment]
})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combine both datasets into one for easier plotting
bestsellers['Group'] = 'Bestsellers'
nonbestsellers['Group'] = 'Non-Bestsellers'

# Concatenate both DataFrames
combined_df = pd.concat([bestsellers[['compound_sentiment', 'Group']], nonbestsellers[['compound_sentiment', 'Group']]])

# Create the violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Group', y='compound_sentiment', data=combined_df, palette='Set2')

# Customize the plot
plt.title('Box of Compound Sentiment for Bestsellers vs. Non-Bestsellers')
plt.xlabel('Group')
plt.ylabel('Compound Sentiment')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a new DataFrame 
sentiment_data = pd.concat([bestsellers['compound_sentiment'], nonbestsellers['compound_sentiment']], axis=0)
sentiment_data = pd.DataFrame({
    'Compound Sentiment': sentiment_data,
    'Group': ['Bestsellers'] * len(bestsellers) + ['Non-Bestsellers'] * len(nonbestsellers)
})

# Plotting the boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Compound Sentiment', data=sentiment_data, palette='Set2')

# Adding titles and labels
plt.title('Box Plot of Compound Sentiment for Bestsellers vs. Non-Bestsellers', fontsize=16)
plt.xlabel('Group', fontsize=12)
plt.ylabel('Compound Sentiment', fontsize=12)
plt.savefig("/Users/anumdamani/thesis/EDA/compound_sentiment_boxplot.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## IMAGES

# %%
# NON-BESTSELLER GRID
from PIL import Image
import matplotlib.pyplot as plt
import os

# Define the folder path where images are stored
image_folder = '/Users/anumdamani/thesis/fiction_images/0_nonbestseller_covers'

# List of the image filenames to include
image_files = [
    '0109.jpg', '1066.jpg', '1215.jpg', '1371.jpg',
    '1424.jpg', '1466.jpg', '1473.jpg', '2358.jpg',
    '2393.jpg', '2238.jpg', '2158.jpg', '2127.jpg',
    '1091.jpg', '1185.jpg', '1212.jpg', '2033.jpg'
]

# Load the images
images = []
for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    img = Image.open(image_path)
    images.append(img)

# Create a 4x4 grid of images
fig, axes = plt.subplots(4, 4, figsize=(12, 12))

# Loop through the grid and place each image
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

plt.tight_layout()

# Adjust layout and save the figure
plt.tight_layout()
output_path = '/Users/anumdamani/thesis/EDA/nonbestseller_image_grid.png'  # Specify the output file path
plt.savefig(output_path, dpi=300, bbox_inches='tight')  # Save the grid as a PNG file
plt.close() 

print(f"Image grid saved as {output_path}")
# Out:
# /var/folders/nk/xkv_bvtx08jfbpgtwjq7tbdm0000gn/T/ipykernel_71525/868566253.py:35: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Image grid saved as /Users/anumdamani/thesis/EDA/nonbestseller_image_grid.png

# %%
# BESTSELLER GRID
from PIL import Image
import matplotlib.pyplot as plt
import os

# Define the folder path where images are stored
image_folder = '/Users/anumdamani/thesis/fiction_images/1_bestseller_covers'

# List of the image filenames to include
image_files = [
    '3953.jpg', '3672.jpg', '3619.jpg', '2468.jpg',
    '2453.jpg', '2464.jpg', '2466.jpg', '3062.jpg',
    '3295.jpg', '4024.jpg', '4059.jpg', '4049.jpg',
    '4092.jpg', '4345.jpg', '3898.jpg', '4438.jpg'
]

# Load the images
images = []
for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    img = Image.open(image_path)
    images.append(img)

# Create a 4x4 grid of images
fig, axes = plt.subplots(4, 4, figsize=(12, 12))

# Loop through the grid and place each image
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

plt.tight_layout()
# Adjust layout and save the figure
plt.tight_layout()
output_path = '/Users/anumdamani/thesis/EDA/bestseller_image_grid.png'  # Specify the output file path
plt.savefig(output_path, dpi=300, bbox_inches='tight')  # Save the grid as a PNG
plt.close()  

print(f"Image grid saved as {output_path}")
# Out:
# /var/folders/nk/xkv_bvtx08jfbpgtwjq7tbdm0000gn/T/ipykernel_90899/2921753323.py:34: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Image grid saved as /Users/anumdamani/thesis/EDA/bestseller_image_grid.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns

# Define paths to image folders
bestseller_folder = "/Users/anumdamani/thesis/fiction_images/1_bestseller_covers"
nonbestseller_folder = "/Users/anumdamani/thesis/fiction_images/0_nonbestseller_covers"

# Function to compute RGB histograms efficiently
def compute_rgb_histogram(image_folder, num_bins=50, sample_size=100):
    red_vals, green_vals, blue_vals = [], [], []
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Randomly sample images to avoid memory overload
    sample_files = np.random.choice(image_files, min(len(image_files), sample_size), replace=False)

    for img_name in sample_files:
        img_path = os.path.join(image_folder, img_name)
        image = Image.open(img_path).convert("RGB")
        image = image.resize((150, 150))  # Resize to save memory
        image_array = np.array(image)

        # Flatten and store RGB values
        red_vals.extend(image_array[:, :, 0].flatten())
        green_vals.extend(image_array[:, :, 1].flatten())
        blue_vals.extend(image_array[:, :, 2].flatten())

    # Compute histograms
    red_hist, _ = np.histogram(red_vals, bins=num_bins, range=(0, 255))
    green_hist, _ = np.histogram(green_vals, bins=num_bins, range=(0, 255))
    blue_hist, _ = np.histogram(blue_vals, bins=num_bins, range=(0, 255))

    return red_hist, green_hist, blue_hist

# Compute histograms for bestsellers and non-bestsellers
red_b, green_b, blue_b = compute_rgb_histogram(bestseller_folder)
red_nb, green_nb, blue_nb = compute_rgb_histogram(nonbestseller_folder)

# Plot histograms
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
colors = ['red', 'green', 'blue']
titles = ['Red Channel', 'Green Channel', 'Blue Channel']

for i, (bestseller_hist, nonbestseller_hist, color, title) in enumerate(zip(
        [red_b, green_b, blue_b], [red_nb, green_nb, blue_nb], colors, titles)):

    axes[i].bar(range(50), bestseller_hist, color=color, alpha=0.6, label="Bestsellers")
    axes[i].bar(range(50), nonbestseller_hist, color=color, alpha=0.3, label="Non-Bestsellers")
    axes[i].set_title(title)
    axes[i].set_xlabel("Pixel Intensity Bins")
    axes[i].set_ylabel("Frequency")
    axes[i].legend()

plt.suptitle("RGB Color Channel Distributions for Bestsellers vs. Non-Bestsellers")
plt.tight_layout()
#plt.show()
plt.savefig('/Users/anumdamani/thesis/EDA/color_histograms.png', dpi=300, bbox_inches='tight')
